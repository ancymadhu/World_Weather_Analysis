# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

# %%
#Step 1 - Make an API call

# Import the requests library.
import requests

# Import the API key.
from Config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f93bc18312e29cefed48ba8db33ca521

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 604

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | hilo
# Processing Record 2 of Set 1 | avarua
# Processing Record 3 of Set 1 | kismayo
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | guigue
# Processing Record 6 of Set 1 | new norfolk
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | mataura
# Processing Record 9 of Set 1 | bandarbeyla
# Processing Record 10 of Set 1 | lithakia
# Processing Record 11 of Set 1 | callaway
# Processing Record 12 of Set 1 | coihaique
# Processing Record 13 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 1 | narsaq
# Processing Record 15 of Set 1 | tasiilaq
# Processing Record 16 of Set 1 | tura
# Processing Record 17 of Set 1 | cape town
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | semey
# Processing Record 20 of Set 1 | port alfred
# Processing Record 21 of Set 1 | ribeira grande
# Processing Record 22 of Set 1 | avera
# Processing Record 23 of Set 1 | vaini
# Processing Record 24 of Set 1 | atuona
# Processing Record 25 of Set 1 | alcanena
# Processing Record 26 of Set 1 | hobart
# Processing Record 27 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 1 | adrar
# Processing Record 29 of Set 1 | beloha
# Processing Record 30 of Set 1 | azul
# Processing Record 31 of Set 1 | anito
# Processing Record 32 of Set 1 | ngukurr
# City not found. Skipping...
# Processing Record 33 of Set 1 | misratah
# Processing Record 34 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 1 | mandera
# Processing Record 36 of Set 1 | bluff
# Processing Record 37 of Set 1 | korem
# Processing Record 38 of Set 1 | san jose
# Processing Record 39 of Set 1 | qaanaaq
# Processing Record 40 of Set 1 | pulo
# Processing Record 41 of Set 1 | tilichiki
# Processing Record 42 of Set 1 | pimenta bueno
# Processing Record 43 of Set 1 | faanui
# Processing Record 44 of Set 1 | college
# Processing Record 45 of Set 1 | itarema
# Processing Record 46 of Set 1 | castro
# Processing Record 47 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 1 | severo-kurilsk
# Processing Record 49 of Set 1 | sataua
# City not found. Skipping...
# Processing Record 50 of Set 1 | provideniya
# Processing Record 1 of Set 2 | mirador
# Processing Record 2 of Set 2 | chama
# Processing Record 3 of Set 2 | albany
# Processing Record 4 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 5 of Set 2 | moranbah
# Processing Record 6 of Set 2 | stepnogorsk
# Processing Record 7 of Set 2 | alofi
# Processing Record 8 of Set 2 | longyearbyen
# Processing Record 9 of Set 2 | bengkulu
# Processing Record 10 of Set 2 | kotma
# Processing Record 11 of Set 2 | butaritari
# Processing Record 12 of Set 2 | barawe
# City not found. Skipping...
# Processing Record 13 of Set 2 | arraial do cabo
# Processing Record 14 of Set 2 | diego de almagro
# Processing Record 15 of Set 2 | busselton
# Processing Record 16 of Set 2 | manjacaze
# Processing Record 17 of Set 2 | san cristobal
# Processing Record 18 of Set 2 | madras
# Processing Record 19 of Set 2 | lagoa
# Processing Record 20 of Set 2 | east london
# Processing Record 21 of Set 2 | clyde river
# Processing Record 22 of Set 2 | barrow
# Processing Record 23 of Set 2 | jamestown
# Processing Record 24 of Set 2 | mantua
# Processing Record 25 of Set 2 | wangqing
# Processing Record 26 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 2 | sooke
# Processing Record 28 of Set 2 | beyneu
# Processing Record 29 of Set 2 | geraldton
# Processing Record 30 of Set 2 | calabozo
# Processing Record 31 of Set 2 | thiruvananthapuram
# Processing Record 32 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 2 | kapaa
# Processing Record 34 of Set 2 | nanortalik
# Processing Record 35 of Set 2 | manakara
# Processing Record 36 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 38 of Set 2 | eureka
# Processing Record 39 of Set 2 | zenzeli
# Processing Record 40 of Set 2 | haines junction
# Processing Record 41 of Set 2 | kumluca
# Processing Record 42 of Set 2 | kedgwick
# Processing Record 43 of Set 2 | ughelli
# Processing Record 44 of Set 2 | opuwo
# Processing Record 45 of Set 2 | saint-philippe
# Processing Record 46 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 2 | iqaluit
# Processing Record 49 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 50 of Set 2 | thompson
# Processing Record 1 of Set 3 | talnakh
# Processing Record 2 of Set 3 | torbay
# Processing Record 3 of Set 3 | bredasdorp
# Processing Record 4 of Set 3 | souillac
# Processing Record 5 of Set 3 | samfya
# Processing Record 6 of Set 3 | amga
# Processing Record 7 of Set 3 | tuktoyaktuk
# Processing Record 8 of Set 3 | sola
# Processing Record 9 of Set 3 | hermanus
# Processing Record 10 of Set 3 | mount isa
# Processing Record 11 of Set 3 | tezu
# Processing Record 12 of Set 3 | tiksi
# Processing Record 13 of Set 3 | tautira
# Processing Record 14 of Set 3 | shingu
# Processing Record 15 of Set 3 | mayumba
# Processing Record 16 of Set 3 | elliot
# Processing Record 17 of Set 3 | chokurdakh
# Processing Record 18 of Set 3 | hithadhoo
# Processing Record 19 of Set 3 | gazanjyk
# Processing Record 20 of Set 3 | pangai
# Processing Record 21 of Set 3 | coquimbo
# Processing Record 22 of Set 3 | kostomuksha
# Processing Record 23 of Set 3 | northam
# Processing Record 24 of Set 3 | dikson
# Processing Record 25 of Set 3 | howard springs
# Processing Record 26 of Set 3 | athabasca
# Processing Record 27 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 28 of Set 3 | milyutinskaya
# Processing Record 29 of Set 3 | yaan
# Processing Record 30 of Set 3 | huarmey
# Processing Record 31 of Set 3 | morant bay
# Processing Record 32 of Set 3 | esperance
# Processing Record 33 of Set 3 | nizhniy ingash
# Processing Record 34 of Set 3 | saint-pierre
# Processing Record 35 of Set 3 | bubaque
# Processing Record 36 of Set 3 | nikolskoye
# Processing Record 37 of Set 3 | honnali
# Processing Record 38 of Set 3 | sisimiut
# Processing Record 39 of Set 3 | klaksvik
# Processing Record 40 of Set 3 | baneh
# Processing Record 41 of Set 3 | la ronge
# Processing Record 42 of Set 3 | dingle
# Processing Record 43 of Set 3 | constitucion
# Processing Record 44 of Set 3 | raudeberg
# Processing Record 45 of Set 3 | wanaka
# Processing Record 46 of Set 3 | tokur
# Processing Record 47 of Set 3 | airai
# Processing Record 48 of Set 3 | kupang
# Processing Record 49 of Set 3 | guerrero negro
# Processing Record 50 of Set 3 | ratnagiri
# Processing Record 1 of Set 4 | kadoma
# Processing Record 2 of Set 4 | kawalu
# Processing Record 3 of Set 4 | batemans bay
# Processing Record 4 of Set 4 | sao filipe
# Processing Record 5 of Set 4 | san vicente de canete
# Processing Record 6 of Set 4 | katsuura
# Processing Record 7 of Set 4 | rapid valley
# Processing Record 8 of Set 4 | matagami
# Processing Record 9 of Set 4 | rosetta
# Processing Record 10 of Set 4 | faya
# Processing Record 11 of Set 4 | mahebourg
# Processing Record 12 of Set 4 | tigil
# Processing Record 13 of Set 4 | vuktyl
# Processing Record 14 of Set 4 | barbar
# City not found. Skipping...
# Processing Record 15 of Set 4 | tucurui
# Processing Record 16 of Set 4 | carnarvon
# Processing Record 17 of Set 4 | tagusao
# Processing Record 18 of Set 4 | port hardy
# Processing Record 19 of Set 4 | ilulissat
# Processing Record 20 of Set 4 | miles city
# Processing Record 21 of Set 4 | vao
# Processing Record 22 of Set 4 | kruisfontein
# Processing Record 23 of Set 4 | acajutla
# Processing Record 24 of Set 4 | hobyo
# Processing Record 25 of Set 4 | farafangana
# Processing Record 26 of Set 4 | sabzevar
# Processing Record 27 of Set 4 | bonthe
# Processing Record 28 of Set 4 | tari
# Processing Record 29 of Set 4 | port blair
# Processing Record 30 of Set 4 | aden
# Processing Record 31 of Set 4 | bulungu
# Processing Record 32 of Set 4 | pevek
# Processing Record 33 of Set 4 | jian
# Processing Record 34 of Set 4 | margate
# Processing Record 35 of Set 4 | saint george
# Processing Record 36 of Set 4 | victoria
# Processing Record 37 of Set 4 | yulara
# Processing Record 38 of Set 4 | lebu
# Processing Record 39 of Set 4 | hihifo
# City not found. Skipping...
# Processing Record 40 of Set 4 | hun
# Processing Record 41 of Set 4 | dvinskoy
# Processing Record 42 of Set 4 | vostok
# Processing Record 43 of Set 4 | vila velha
# Processing Record 44 of Set 4 | tifton
# Processing Record 45 of Set 4 | asosa
# Processing Record 46 of Set 4 | kattivakkam
# Processing Record 47 of Set 4 | camabatela
# Processing Record 48 of Set 4 | buala
# Processing Record 49 of Set 4 | kavieng
# Processing Record 50 of Set 4 | cidreira
# Processing Record 1 of Set 5 | vardo
# Processing Record 2 of Set 5 | shenjiamen
# Processing Record 3 of Set 5 | prince rupert
# Processing Record 4 of Set 5 | riyadh
# Processing Record 5 of Set 5 | kavaratti
# Processing Record 6 of Set 5 | haverfordwest
# Processing Record 7 of Set 5 | mixtepec
# City not found. Skipping...
# Processing Record 8 of Set 5 | port hueneme
# Processing Record 9 of Set 5 | saldanha
# Processing Record 10 of Set 5 | bilma
# Processing Record 11 of Set 5 | yellowknife
# Processing Record 12 of Set 5 | maple creek
# Processing Record 13 of Set 5 | myskhako
# Processing Record 14 of Set 5 | half moon bay
# Processing Record 15 of Set 5 | liverpool
# Processing Record 16 of Set 5 | chiriqui grande
# Processing Record 17 of Set 5 | moscow
# Processing Record 18 of Set 5 | huaihua
# Processing Record 19 of Set 5 | pisco
# Processing Record 20 of Set 5 | yar-sale
# Processing Record 21 of Set 5 | vila franca do campo
# Processing Record 22 of Set 5 | hamilton
# Processing Record 23 of Set 5 | iracoubo
# Processing Record 24 of Set 5 | yurya
# City not found. Skipping...
# Processing Record 25 of Set 5 | barra do garcas
# Processing Record 26 of Set 5 | oshawa
# Processing Record 27 of Set 5 | norman wells
# Processing Record 28 of Set 5 | tyukalinsk
# Processing Record 29 of Set 5 | jingdezhen
# Processing Record 30 of Set 5 | pucallpa
# Processing Record 31 of Set 5 | ancud
# Processing Record 32 of Set 5 | vikulovo
# Processing Record 33 of Set 5 | codajas
# Processing Record 34 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 35 of Set 5 | kaitangata
# Processing Record 36 of Set 5 | puerto ayora
# Processing Record 37 of Set 5 | hasaki
# Processing Record 38 of Set 5 | yoichi
# Processing Record 39 of Set 5 | yingkou
# Processing Record 40 of Set 5 | barsovo
# Processing Record 41 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 42 of Set 5 | nabire
# Processing Record 43 of Set 5 | poopo
# Processing Record 44 of Set 5 | skalistyy
# City not found. Skipping...
# Processing Record 45 of Set 5 | gameza
# Processing Record 46 of Set 5 | saskylakh
# Processing Record 47 of Set 5 | ban nahin
# Processing Record 48 of Set 5 | cabedelo
# Processing Record 49 of Set 5 | polyarnyy
# Processing Record 50 of Set 5 | presidente medici
# Processing Record 1 of Set 6 | lompoc
# Processing Record 2 of Set 6 | qaqortoq
# Processing Record 3 of Set 6 | mocambique
# City not found. Skipping...
# Processing Record 4 of Set 6 | behshahr
# Processing Record 5 of Set 6 | georgetown
# Processing Record 6 of Set 6 | juifang
# City not found. Skipping...
# Processing Record 7 of Set 6 | conde
# Processing Record 8 of Set 6 | broome
# Processing Record 9 of Set 6 | ixtapa
# Processing Record 10 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 6 | parana
# Processing Record 12 of Set 6 | slupsk
# Processing Record 13 of Set 6 | taltal
# Processing Record 14 of Set 6 | ingham
# Processing Record 15 of Set 6 | teya
# Processing Record 16 of Set 6 | bambous virieux
# Processing Record 17 of Set 6 | whitehorse
# Processing Record 18 of Set 6 | marovoay
# Processing Record 19 of Set 6 | oranjemund
# Processing Record 20 of Set 6 | sibu
# Processing Record 21 of Set 6 | shaowu
# Processing Record 22 of Set 6 | chuy
# Processing Record 23 of Set 6 | san patricio
# Processing Record 24 of Set 6 | port elizabeth
# Processing Record 25 of Set 6 | kodiak
# Processing Record 26 of Set 6 | oktyabrskiy
# Processing Record 27 of Set 6 | ponta do sol
# Processing Record 28 of Set 6 | henties bay
# Processing Record 29 of Set 6 | manokwari
# Processing Record 30 of Set 6 | upernavik
# Processing Record 31 of Set 6 | sitka
# Processing Record 32 of Set 6 | lakhnadon
# Processing Record 33 of Set 6 | safaga
# Processing Record 34 of Set 6 | luneville
# Processing Record 35 of Set 6 | uyemskiy
# Processing Record 36 of Set 6 | komsomolskiy
# Processing Record 37 of Set 6 | lorengau
# Processing Record 38 of Set 6 | rawson
# Processing Record 39 of Set 6 | berlevag
# Processing Record 40 of Set 6 | aguimes
# Processing Record 41 of Set 6 | laguna
# Processing Record 42 of Set 6 | anadyr
# Processing Record 43 of Set 6 | tawnat
# City not found. Skipping...
# Processing Record 44 of Set 6 | chifeng
# Processing Record 45 of Set 6 | cabo san lucas
# Processing Record 46 of Set 6 | abbeville
# Processing Record 47 of Set 6 | boddam
# Processing Record 48 of Set 6 | the pas
# Processing Record 49 of Set 6 | yuzha
# Processing Record 50 of Set 6 | kamsack
# Processing Record 1 of Set 7 | nong kung si
# Processing Record 2 of Set 7 | khatanga
# Processing Record 3 of Set 7 | namatanai
# Processing Record 4 of Set 7 | vaxjo
# Processing Record 5 of Set 7 | naftah
# City not found. Skipping...
# Processing Record 6 of Set 7 | cherskiy
# Processing Record 7 of Set 7 | bakel
# Processing Record 8 of Set 7 | olafsvik
# Processing Record 9 of Set 7 | mana
# Processing Record 10 of Set 7 | gwadar
# Processing Record 11 of Set 7 | dickinson
# Processing Record 12 of Set 7 | kem
# Processing Record 13 of Set 7 | guadalupe y calvo
# Processing Record 14 of Set 7 | ucluelet
# Processing Record 15 of Set 7 | mayo
# Processing Record 16 of Set 7 | kaoma
# Processing Record 17 of Set 7 | yamada
# Processing Record 18 of Set 7 | buchanan
# Processing Record 19 of Set 7 | mercedes
# Processing Record 20 of Set 7 | san vicente
# Processing Record 21 of Set 7 | ahipara
# Processing Record 22 of Set 7 | daur
# Processing Record 23 of Set 7 | freeport
# Processing Record 24 of Set 7 | constantine
# Processing Record 25 of Set 7 | daru
# Processing Record 26 of Set 7 | rawah
# Processing Record 27 of Set 7 | laredo
# Processing Record 28 of Set 7 | kalmunai
# Processing Record 29 of Set 7 | cockburn town
# Processing Record 30 of Set 7 | zvenyhorodka
# Processing Record 31 of Set 7 | great yarmouth
# Processing Record 32 of Set 7 | baljevac
# Processing Record 33 of Set 7 | fortuna
# Processing Record 34 of Set 7 | padang
# Processing Record 35 of Set 7 | indramayu
# Processing Record 36 of Set 7 | conway
# Processing Record 37 of Set 7 | safwah
# City not found. Skipping...
# Processing Record 38 of Set 7 | bonfim
# Processing Record 39 of Set 7 | beckingen
# Processing Record 40 of Set 7 | kasama
# Processing Record 41 of Set 7 | sao miguel do araguaia
# Processing Record 42 of Set 7 | mar del plata
# Processing Record 43 of Set 7 | banavar
# Processing Record 44 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 7 | wattegama
# Processing Record 46 of Set 7 | udala
# Processing Record 47 of Set 7 | mehamn
# Processing Record 48 of Set 7 | jalu
# Processing Record 49 of Set 7 | goderich
# Processing Record 50 of Set 7 | galgani
# City not found. Skipping...
# Processing Record 1 of Set 8 | nouadhibou
# Processing Record 2 of Set 8 | nelson bay
# Processing Record 3 of Set 8 | ustye
# Processing Record 4 of Set 8 | lere
# Processing Record 5 of Set 8 | bethel
# Processing Record 6 of Set 8 | nuuk
# Processing Record 7 of Set 8 | vestbygda
# City not found. Skipping...
# Processing Record 8 of Set 8 | codrington
# Processing Record 9 of Set 8 | ferme-neuve
# Processing Record 10 of Set 8 | asuncion
# Processing Record 11 of Set 8 | presidencia roque saenz pena
# Processing Record 12 of Set 8 | newport
# Processing Record 13 of Set 8 | grindavik
# Processing Record 14 of Set 8 | dunedin
# Processing Record 15 of Set 8 | fez
# Processing Record 16 of Set 8 | ulundi
# Processing Record 17 of Set 8 | serebryansk
# Processing Record 18 of Set 8 | puerto quijarro
# Processing Record 19 of Set 8 | aklavik
# Processing Record 20 of Set 8 | acatlan
# Processing Record 21 of Set 8 | myitkyina
# Processing Record 22 of Set 8 | mecca
# Processing Record 23 of Set 8 | poum
# Processing Record 24 of Set 8 | novoagansk
# Processing Record 25 of Set 8 | ijui
# Processing Record 26 of Set 8 | qixingtai
# Processing Record 27 of Set 8 | lawrenceburg
# Processing Record 28 of Set 8 | vestmannaeyjar
# Processing Record 29 of Set 8 | chudovo
# Processing Record 30 of Set 8 | sanchursk
# Processing Record 31 of Set 8 | lubumbashi
# Processing Record 32 of Set 8 | davila
# Processing Record 33 of Set 8 | barsi
# Processing Record 34 of Set 8 | krasnoselkup
# Processing Record 35 of Set 8 | kommunisticheskiy
# Processing Record 36 of Set 8 | muros
# Processing Record 37 of Set 8 | bathsheba
# Processing Record 38 of Set 8 | lincoln
# Processing Record 39 of Set 8 | trapani
# Processing Record 40 of Set 8 | saint-francois
# Processing Record 41 of Set 8 | catuday
# Processing Record 42 of Set 8 | nemuro
# Processing Record 43 of Set 8 | sao joao da barra
# Processing Record 44 of Set 8 | bonavista
# Processing Record 45 of Set 8 | dolbeau
# City not found. Skipping...
# Processing Record 46 of Set 8 | chingirlau
# Processing Record 47 of Set 8 | ayna
# Processing Record 48 of Set 8 | ozgon
# City not found. Skipping...
# Processing Record 49 of Set 8 | nowogard
# Processing Record 50 of Set 8 | abu dhabi
# Processing Record 1 of Set 9 | ranghulu
# Processing Record 2 of Set 9 | flinders
# Processing Record 3 of Set 9 | cap malheureux
# Processing Record 4 of Set 9 | labytnangi
# Processing Record 5 of Set 9 | santiago de cao
# Processing Record 6 of Set 9 | balagansk
# Processing Record 7 of Set 9 | gasa
# Processing Record 8 of Set 9 | sur
# Processing Record 9 of Set 9 | aykhal
# Processing Record 10 of Set 9 | acarau
# Processing Record 11 of Set 9 | haltom city
# Processing Record 12 of Set 9 | zhigansk
# Processing Record 13 of Set 9 | strezhevoy
# Processing Record 14 of Set 9 | tuatapere
# Processing Record 15 of Set 9 | vanimo
# Processing Record 16 of Set 9 | rio grande
# Processing Record 17 of Set 9 | corrales
# Processing Record 18 of Set 9 | asau
# Processing Record 19 of Set 9 | kapitanivka
# Processing Record 20 of Set 9 | roccastrada
# Processing Record 21 of Set 9 | bolshaya murta
# City not found. Skipping...
# Processing Record 22 of Set 9 | salinas
# Processing Record 23 of Set 9 | chake chake
# Processing Record 24 of Set 9 | lakes entrance
# Processing Record 25 of Set 9 | marsh harbour
# Processing Record 26 of Set 9 | bogande
# Processing Record 27 of Set 9 | yeppoon
# Processing Record 28 of Set 9 | zhezkazgan
# Processing Record 29 of Set 9 | hofn
# Processing Record 30 of Set 9 | botwood
# Processing Record 31 of Set 9 | touros
# Processing Record 32 of Set 9 | chapais
# Processing Record 33 of Set 9 | bestobe
# Processing Record 34 of Set 9 | taoudenni
# Processing Record 35 of Set 9 | toktogul
# Processing Record 36 of Set 9 | salinopolis
# Processing Record 37 of Set 9 | sicuani
# Processing Record 38 of Set 9 | kvareli
# Processing Record 39 of Set 9 | pundaguitan
# Processing Record 40 of Set 9 | beringovskiy
# Processing Record 41 of Set 9 | barranca
# Processing Record 42 of Set 9 | azar shahr
# City not found. Skipping...
# Processing Record 43 of Set 9 | moose factory
# Processing Record 44 of Set 9 | leningradskiy
# Processing Record 45 of Set 9 | port lincoln
# Processing Record 46 of Set 9 | camargo
# Processing Record 47 of Set 9 | kayes
# Processing Record 48 of Set 9 | samarai
# Processing Record 49 of Set 9 | amuntai
# Processing Record 50 of Set 9 | sobolevo
# Processing Record 1 of Set 10 | shamkhal
# Processing Record 2 of Set 10 | camacha
# Processing Record 3 of Set 10 | peniche
# Processing Record 4 of Set 10 | lerwick
# Processing Record 5 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 6 of Set 10 | poniatowa
# Processing Record 7 of Set 10 | mount gambier
# Processing Record 8 of Set 10 | russellville
# Processing Record 9 of Set 10 | san carlos de bariloche
# Processing Record 10 of Set 10 | naze
# Processing Record 11 of Set 10 | vangaindrano
# Processing Record 12 of Set 10 | podporozhye
# Processing Record 13 of Set 10 | balykshi
# Processing Record 14 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 10 | aswan
# Processing Record 16 of Set 10 | penzance
# Processing Record 17 of Set 10 | paita
# Processing Record 18 of Set 10 | tawang
# Processing Record 19 of Set 10 | umm lajj
# Processing Record 20 of Set 10 | perigueux
# Processing Record 21 of Set 10 | feijo
# Processing Record 22 of Set 10 | shakawe
# Processing Record 23 of Set 10 | nome
# Processing Record 24 of Set 10 | hambantota
# Processing Record 25 of Set 10 | novochernorechenskiy
# Processing Record 26 of Set 10 | luderitz
# Processing Record 27 of Set 10 | moron
# Processing Record 28 of Set 10 | batagay
# Processing Record 29 of Set 10 | orodara
# Processing Record 30 of Set 10 | los llanos de aridane
# Processing Record 31 of Set 10 | juba
# Processing Record 32 of Set 10 | fort nelson
# Processing Record 33 of Set 10 | pinsk
# Processing Record 34 of Set 10 | qiyang
# Processing Record 35 of Set 10 | ponca city
# Processing Record 36 of Set 10 | hornepayne
# Processing Record 37 of Set 10 | nishihara
# Processing Record 38 of Set 10 | mamallapuram
# Processing Record 39 of Set 10 | ulaangom
# Processing Record 40 of Set 10 | aksarka
# Processing Record 41 of Set 10 | babanusah
# City not found. Skipping...
# Processing Record 42 of Set 10 | isla mujeres
# Processing Record 43 of Set 10 | clyde
# Processing Record 44 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 45 of Set 10 | waitati
# Processing Record 46 of Set 10 | valmiera
# Processing Record 47 of Set 10 | mitchell
# Processing Record 48 of Set 10 | rocha
# Processing Record 49 of Set 10 | helong
# Processing Record 50 of Set 10 | nizhneangarsk
# Processing Record 1 of Set 11 | ussel
# Processing Record 2 of Set 11 | ziniare
# Processing Record 3 of Set 11 | baoding
# Processing Record 4 of Set 11 | uvinza
# Processing Record 5 of Set 11 | linxia
# Processing Record 6 of Set 11 | lumby
# Processing Record 7 of Set 11 | chumikan
# Processing Record 8 of Set 11 | east moline
# Processing Record 9 of Set 11 | lishu
# Processing Record 10 of Set 11 | pangnirtung
# Processing Record 11 of Set 11 | pleasanton
# Processing Record 12 of Set 11 | igarka
# Processing Record 13 of Set 11 | okhotsk
# Processing Record 14 of Set 11 | patuli
# Processing Record 15 of Set 11 | majene
# Processing Record 16 of Set 11 | juneau
# Processing Record 17 of Set 11 | manica
# Processing Record 18 of Set 11 | lavrentiya
# Processing Record 19 of Set 11 | pestovo
# Processing Record 20 of Set 11 | mahenge
# Processing Record 21 of Set 11 | crab hill
# City not found. Skipping...
# Processing Record 22 of Set 11 | reggio di calabria
# Processing Record 23 of Set 11 | avezzano
# Processing Record 24 of Set 11 | mananjary
# Processing Record 25 of Set 11 | nacogdoches
# Processing Record 26 of Set 11 | egvekinot
# Processing Record 27 of Set 11 | necochea
# Processing Record 28 of Set 11 | inhambane
# Processing Record 29 of Set 11 | ambulu
# Processing Record 30 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 11 | vanavara
# Processing Record 32 of Set 11 | gumdag
# Processing Record 33 of Set 11 | lujan
# Processing Record 34 of Set 11 | tymovskoye
# Processing Record 35 of Set 11 | tripoli
# Processing Record 36 of Set 11 | hwange
# Processing Record 37 of Set 11 | the valley
# Processing Record 38 of Set 11 | korba
# Processing Record 39 of Set 11 | dargaville
# Processing Record 40 of Set 11 | shalazhi
# Processing Record 41 of Set 11 | tommot
# Processing Record 42 of Set 11 | pochutla
# Processing Record 43 of Set 11 | pontes e lacerda
# Processing Record 44 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 45 of Set 11 | algiers
# Processing Record 46 of Set 11 | tazovskiy
# Processing Record 47 of Set 11 | high level
# Processing Record 48 of Set 11 | thinadhoo
# Processing Record 49 of Set 11 | vyartsilya
# Processing Record 50 of Set 11 | rafai
# Processing Record 1 of Set 12 | wahran
# City not found. Skipping...
# Processing Record 2 of Set 12 | alur
# Processing Record 3 of Set 12 | yamethin
# Processing Record 4 of Set 12 | salalah
# Processing Record 5 of Set 12 | kamaishi
# Processing Record 6 of Set 12 | strai
# Processing Record 7 of Set 12 | buraydah
# Processing Record 8 of Set 12 | dutse
# Processing Record 9 of Set 12 | glyadyanskoye
# Processing Record 10 of Set 12 | santiago
# Processing Record 11 of Set 12 | gimli
# Processing Record 12 of Set 12 | sao joao da ponte
# Processing Record 13 of Set 12 | huanuni
# Processing Record 14 of Set 12 | salto
# Processing Record 15 of Set 12 | fairview
# Processing Record 16 of Set 12 | appiano
# City not found. Skipping...
# Processing Record 17 of Set 12 | talcahuano
# Processing Record 18 of Set 12 | yefimovskiy
# City not found. Skipping...
# Processing Record 19 of Set 12 | russell
# Processing Record 20 of Set 12 | ambon
# Processing Record 21 of Set 12 | zhob
# Processing Record 22 of Set 12 | griffith
# Processing Record 23 of Set 12 | antalaha
# Processing Record 24 of Set 12 | marzuq
# Processing Record 25 of Set 12 | tabou
# Processing Record 26 of Set 12 | asyut
# Processing Record 27 of Set 12 | iringa
# Processing Record 28 of Set 12 | sabang
# Processing Record 29 of Set 12 | kichmengskiy gorodok
# Processing Record 30 of Set 12 | cariamanga
# Processing Record 31 of Set 12 | pulsano
# Processing Record 32 of Set 12 | lakatoro
# Processing Record 33 of Set 12 | clarence town
# Processing Record 34 of Set 12 | ostrovnoy
# Processing Record 35 of Set 12 | isangel
# Processing Record 36 of Set 12 | sompeta
# Processing Record 37 of Set 12 | alim
# Processing Record 38 of Set 12 | medina
# Processing Record 39 of Set 12 | ambodifototra
# City not found. Skipping...
# Processing Record 40 of Set 12 | srednekolymsk
# Processing Record 41 of Set 12 | pueblo
# Processing Record 42 of Set 12 | yomou
# Processing Record 43 of Set 12 | ariquemes
# Processing Record 44 of Set 12 | orda
# Processing Record 45 of Set 12 | cobija
# Processing Record 46 of Set 12 | suntar
# Processing Record 47 of Set 12 | mahon
# Processing Record 48 of Set 12 | ramhormoz
# Processing Record 49 of Set 12 | banda aceh
# Processing Record 50 of Set 12 | sentyabrskiy
# City not found. Skipping...
# Processing Record 1 of Set 13 | phalombe
# Processing Record 2 of Set 13 | poindimie
# Processing Record 3 of Set 13 | pitimbu
# Processing Record 4 of Set 13 | valle hermoso
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0         Hilo      US  19.73 -155.09     80.60        65          75
# 1       Avarua      CK -21.21 -159.78     80.60        74          89
# 2      Kismayo      SO  -0.36   42.55     80.26        82          76
# 3      Rikitea      PF -23.12 -134.97     76.23        79         100
# 4       Guigue      VE  10.09  -67.78     73.02        89          97
# 5  New Norfolk      AU -42.78  147.06     72.00        38          99
# 6      Ushuaia      AR -54.80  -68.30     37.40        86          40
# 7      Mataura      NZ -46.19  168.86     61.00        53         100
# 8  Bandarbeyla      SO   9.49   50.81     74.68        78          55
# 9     Lithakia      GR  37.72   20.83     48.20        76           0
#
#    Wind Speed Current Description
# 0       12.75       broken clouds
# 1       23.04     overcast clouds
# 2       12.37          light rain
# 3       18.28     overcast clouds
# 4        3.49     overcast clouds
# 5        5.01     overcast clouds
# 6        9.17         shower rain
# 7        1.99     overcast clouds
# 8       14.63       broken clouds
# 9        4.70           clear sky

# %%
# Create the output file (CSV).
output_data_file = r"C:\Users\ancya\Documents\Weather_Database\WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
